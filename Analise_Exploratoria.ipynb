# %% [markdown]
# # Análise Exploratória

# %% [markdown]
# ## Importações

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# ## Leitura do Arquivo
#
# Os dados da ouvidorias estão em formato csv separados por "|". Nesta etapa vamos conhecer o dataset

# %%
df = pd.read_csv('dados.csv', sep='|')
df
# Out:
#                    Abertura  Identificada       Situação Classificação  \
# 0       01/01/2022 00:11:43          True     Respondida        Elogio
# 1       01/01/2022 00:53:06          True  Não Resolvida    Reclamação
# 2       01/01/2022 01:51:00          True     Respondida   Solicitação
# 3       01/01/2022 02:27:15         False     Respondida    Reclamação
# 4       01/01/2022 02:50:06         False     Respondida    Reclamação
# ...                     ...           ...            ...           ...
# 133164  05/05/2022 21:00:27         False       Recebida      Denúncia
# 133165  05/05/2022 21:07:18          True       Recebida    Reclamação
# 133166  05/05/2022 21:08:57          True       Recebida        Elogio
# 133167  05/05/2022 21:13:10          True       Recebida    Reclamação
# 133168  05/05/2022 21:13:43          True       Recebida   Solicitação
#
#                                                   Assunto  \
# 0                                        Praças e jardins
# 1                                      Corpo de Bombeiros
# 2                      Iluminação Pública (Funcionamento)
# 3                                        Servidor Público
# 4                                         Polícia militar
# ...                                                   ...
# 133164                                   Servidor Público
# 133165  Manutenção e Segurança de Parques e Unidades d...
# 133166                             Visitação no zoológico
# 133167                           Agendamento de Cirurgias
# 133168                 Iluminação Pública (Funcionamento)
#
#                Região_Administrativa  \
# 0          RA RFI (Riacho Fundo - I)
# 1                RA CEIL (Ceilândia)
# 2        RA SOBRII (Sobradinho - II)
# 3                RA CEIL (Ceilândia)
# 4                    RA GUAR (Guará)
# ...                              ...
# 133164          RA-PP (Plano Piloto)
# 133165  RA SUDO (Sudoeste/Octogonal)
# 133166          RA-PP (Plano Piloto)
# 133167          RA-PP (Plano Piloto)
# 133168          RA ARNQ (Arniqueira)
#
#                                                   Unidade  \
# 0       NOVACAP - Companhia Urbanizadora da Nova Capit...
# 1       CBMDF - Corpo de Bombeiros Militar do Distrito...
# 2       Coordenação de Manutenção de Iluminação Públic...
# 3       SES - Secretaria de Estado de Saúde do Distrit...
# 4              PMDF - Polícia Militar do Distrito Federal
# ...                                                   ...
# 133164  COACI/OGDF - Coordenação de Atendimento ao cid...
# 133165  IBRAM - Instituto do Meio Ambiente e Recursos ...
# 133166       FJZB - Fundação Jardim Zoológico de Brasilia
# 133167  SES - Secretaria de Estado de Saúde do Distrit...
# 133168  SODF - Secretaria de Estado de Obras e Infraes...
#
#                                                     Orgao Tipo_Entrada
# 0       NOVACAP - Companhia Urbanizadora da Nova Capit...     INTERNET
# 1       CBMDF - Corpo de Bombeiros Militar do Distrito...     INTERNET
# 2       SODF - Secretaria de Estado de Obras e Infraes...     INTERNET
# 3       SES - Secretaria de Estado de Saúde do Distrit...     INTERNET
# 4              PMDF - Polícia Militar do Distrito Federal     INTERNET
# ...                                                   ...          ...
# 133164  COACI/OGDF - Coordenação de Atendimento ao cid...     INTERNET
# 133165  IBRAM - Instituto do Meio Ambiente e Recursos ...     INTERNET
# 133166       FJZB - Fundação Jardim Zoológico de Brasilia     INTERNET
# 133167  SES - Secretaria de Estado de Saúde do Distrit...     INTERNET
# 133168  SODF - Secretaria de Estado de Obras e Infraes...     INTERNET
#
# [133169 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133169 entries, 0 to 133168
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Abertura               133169 non-null  object
#  1   Identificada           133169 non-null  bool
#  2   Situação               133169 non-null  object
#  3   Classificação          133169 non-null  object
#  4   Assunto                133169 non-null  object
#  5   Região_Administrativa  133169 non-null  object
#  6   Unidade                133169 non-null  object
#  7   Orgao                  133169 non-null  object
#  8   Tipo_Entrada           133169 non-null  object
# dtypes: bool(1), object(8)
# memory usage: 8.3+ MB

# %%
df.shape
# Out:
# (133169, 9)

# %% [markdown]
# ## Tratamento
#
# Esses códigos serão reescritos no arquivo .py principal de tratamento, pelo jupyter notebook é mais rápido para testarmos algumas hipoteses.

# %% [markdown]
# ### Criação de Uma Coluna com o Apelido do Orgão
#
# O campo "Orgao" contém, o apelido do Órgão e o nome completo, basta separarmos pelo delimitador " - " e abreviar a palavra "Administração" presentes em aguns regristro

# %%
df.Orgao
# Out:
# 0         NOVACAP - Companhia Urbanizadora da Nova Capit...
# 1         CBMDF - Corpo de Bombeiros Militar do Distrito...
# 2         SODF - Secretaria de Estado de Obras e Infraes...
# 3         SES - Secretaria de Estado de Saúde do Distrit...
# 4                PMDF - Polícia Militar do Distrito Federal
#                                 ...
# 133164    COACI/OGDF - Coordenação de Atendimento ao cid...
# 133165    IBRAM - Instituto do Meio Ambiente e Recursos ...
# 133166         FJZB - Fundação Jardim Zoológico de Brasilia
# 133167    SES - Secretaria de Estado de Saúde do Distrit...
# 133168    SODF - Secretaria de Estado de Obras e Infraes...
# Name: Orgao, Length: 133169, dtype: object

# %%
df[['Apelido', 'temporario']] = df.Orgao.str.split(' - ',1,expand=True)
df['Apelido'] = df['Apelido'].str.replace("Administração", "Adm")
df = df.drop(columns='temporario')

# %%
df.Apelido
# Out:
# 0            NOVACAP
# 1              CBMDF
# 2               SODF
# 3                SES
# 4               PMDF
#              ...
# 133164    COACI/OGDF
# 133165         IBRAM
# 133166          FJZB
# 133167           SES
# 133168          SODF
# Name: Apelido, Length: 133169, dtype: object

# %% [markdown]
# ### Identificando um campo chave
#
# Considere que uma reclamação entra com uma "Situação", por exemplo "Recebida" e depois de uns dias muda para "Respondida", nessa visualização da base estamos vendo apenas a última situação da manifestção, não sendo possível analisar a diferença de tempo entre a troca de situações.
#
# Um campo chave em uma tabela é um valor único em uma coluna, a ideia é que se comparamos um dataset com outro extraído um tempo depois, atravez desse campo chave podemos ver a evolução dos mesmos resgistros e calcularmos o **tempo médio** para responder/resolver as manifestações, ou seja, para funcionar precisamos fazer extrações da base e "congelar as situações" no tempo.

# %%
df.Abertura.value_counts()
# Out:
# 03/30/2022 17:56:35    2
# 04/25/2022 12:42:49    2
# 03/23/2022 10:47:57    2
# 03/23/2022 10:51:30    2
# 02/07/2022 14:37:45    2
#                       ..
# 02/13/2022 13:58:16    1
# 02/13/2022 13:57:02    1
# 02/13/2022 13:54:26    1
# 02/13/2022 13:53:40    1
# 05/05/2022 21:13:43    1
# Name: Abertura, Length: 131886, dtype: int64

# %% [markdown]
# O campo de abertura seria um ótimo candidato para campo chave, contudo esse campo não apresenta valores únicos, teremos que tentar uma outra abordagem

# %%
# Criando um dataset agrupado por todas as colunas exceto Situação
colunas = list(df.columns)
# O índice da coluna "Situação" é 2
del(colunas[2])
df2 = df.groupby(colunas,as_index=False).count()
df2
# Out:
#                    Abertura  Identificada Classificação  \
# 0       01/01/2022 00:11:43          True        Elogio
# 1       01/01/2022 00:53:06          True    Reclamação
# 2       01/01/2022 01:51:00          True   Solicitação
# 3       01/01/2022 02:27:15         False    Reclamação
# 4       01/01/2022 02:50:06         False    Reclamação
# ...                     ...           ...           ...
# 133163  05/05/2022 21:00:27         False      Denúncia
# 133164  05/05/2022 21:07:18          True    Reclamação
# 133165  05/05/2022 21:08:57          True        Elogio
# 133166  05/05/2022 21:13:10          True    Reclamação
# 133167  05/05/2022 21:13:43          True   Solicitação
#
#                                                   Assunto  \
# 0                                        Praças e jardins
# 1                                      Corpo de Bombeiros
# 2                      Iluminação Pública (Funcionamento)
# 3                                        Servidor Público
# 4                                         Polícia militar
# ...                                                   ...
# 133163                                   Servidor Público
# 133164  Manutenção e Segurança de Parques e Unidades d...
# 133165                             Visitação no zoológico
# 133166                           Agendamento de Cirurgias
# 133167                 Iluminação Pública (Funcionamento)
#
#                Região_Administrativa  \
# 0          RA RFI (Riacho Fundo - I)
# 1                RA CEIL (Ceilândia)
# 2        RA SOBRII (Sobradinho - II)
# 3                RA CEIL (Ceilândia)
# 4                    RA GUAR (Guará)
# ...                              ...
# 133163          RA-PP (Plano Piloto)
# 133164  RA SUDO (Sudoeste/Octogonal)
# 133165          RA-PP (Plano Piloto)
# 133166          RA-PP (Plano Piloto)
# 133167          RA ARNQ (Arniqueira)
#
#                                                   Unidade  \
# 0       NOVACAP - Companhia Urbanizadora da Nova Capit...
# 1       CBMDF - Corpo de Bombeiros Militar do Distrito...
# 2       Coordenação de Manutenção de Iluminação Públic...
# 3       SES - Secretaria de Estado de Saúde do Distrit...
# 4              PMDF - Polícia Militar do Distrito Federal
# ...                                                   ...
# 133163  COACI/OGDF - Coordenação de Atendimento ao cid...
# 133164  IBRAM - Instituto do Meio Ambiente e Recursos ...
# 133165       FJZB - Fundação Jardim Zoológico de Brasilia
# 133166  SES - Secretaria de Estado de Saúde do Distrit...
# 133167  SODF - Secretaria de Estado de Obras e Infraes...
#
#                                                     Orgao Tipo_Entrada  \
# 0       NOVACAP - Companhia Urbanizadora da Nova Capit...     INTERNET
# 1       CBMDF - Corpo de Bombeiros Militar do Distrito...     INTERNET
# 2       SODF - Secretaria de Estado de Obras e Infraes...     INTERNET
# 3       SES - Secretaria de Estado de Saúde do Distrit...     INTERNET
# 4              PMDF - Polícia Militar do Distrito Federal     INTERNET
# ...                                                   ...          ...
# 133163  COACI/OGDF - Coordenação de Atendimento ao cid...     INTERNET
# 133164  IBRAM - Instituto do Meio Ambiente e Recursos ...     INTERNET
# 133165       FJZB - Fundação Jardim Zoológico de Brasilia     INTERNET
# 133166  SES - Secretaria de Estado de Saúde do Distrit...     INTERNET
# 133167  SODF - Secretaria de Estado de Obras e Infraes...     INTERNET
#
#         Situação
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 133163         1
# 133164         1
# 133165         1
# 133166         1
# 133167         1
#
# [133168 rows x 9 columns]

# %% [markdown]
# Ao invés de usarmos apenas uma coluna como chave, agora tentaremos buscar a unicidade comparando todas as colunas exceto a Situação, assim quando compararmos os datasets ao longo do tempo poderemos ver a evolução da situação

# %%
df2.query("Situação > 1")
# Out:
#                   Abertura  Identificada Classificação  \
# 72167  03/10/2022 10:49:31          True    Reclamação
#
#                                      Assunto Região_Administrativa  \
# 72167  CRAS - Vagas para atendimento no CRAS  RA-PLAN (Planaltina)
#
#                                                  Unidade  \
# 72167  SEDES - Secretaria de Estado de Desenvolviment...
#
#                                                    Orgao Tipo_Entrada  \
# 72167  SEDES - Secretaria de Estado de Desenvolviment...     TELEFONE
#
#        Situação
# 72167         2

# %% [markdown]
# Apenas 2 registro com todas colunas iguais, vamos analisar no dataset original para analisar quais situações desses registros

# %%
df.query("Abertura == '03/10/2022 10:49:31'")
# Out:
#                   Abertura  Identificada    Situação Classificação  \
# 72167  03/10/2022 10:49:31          True  Respondida    Reclamação
# 72168  03/10/2022 10:49:31          True  Respondida    Reclamação
#
#                                      Assunto Região_Administrativa  \
# 72167  CRAS - Vagas para atendimento no CRAS  RA-PLAN (Planaltina)
# 72168  CRAS - Vagas para atendimento no CRAS  RA-PLAN (Planaltina)
#
#                                                  Unidade  \
# 72167  SEDES - Secretaria de Estado de Desenvolviment...
# 72168  SEDES - Secretaria de Estado de Desenvolviment...
#
#                                                    Orgao Tipo_Entrada
# 72167  SEDES - Secretaria de Estado de Desenvolviment...     TELEFONE
# 72168  SEDES - Secretaria de Estado de Desenvolviment...     TELEFONE

# %% [markdown]
# Como os registros tem a mesma "Situação", então existem 2 possibilidades:
# - Trata-se de um erro e esse dado está duplicado; ou
# - São de fato manifestações distintas.
#
# Para o primeiro caso, essas duas manifestações também teriam dois registro de origem com situação "Recebida", neste caso comprovaria a duplicidade.
#
# Para o segundo caso, essas manifestações teriam apenas uma origem com situação "Recebida", daí basta remover as duplicadas.
#
# Para ambos os caso é possível montar esse banco para realizar essas comparações, vou começar a montar o banco a partir do mês 06/2022
